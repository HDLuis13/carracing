# %%
# %matplotlib inline

import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("images/values.csv")

# %%
data.set_index('timestep', inplace=True)
data.head(20)
# Out:
#               value                                   action
# timestep
# 0         48.374680     [[0.04893747 0.66209245 0.        ]]
# 1         43.277200     [[1.         0.17474365 0.        ]]
# 2         44.949390     [[0.45302045 1.         0.        ]]
# 3         44.128628     [[0.96932286 0.806727   0.        ]]
# 4         45.361200     [[0.16369033 1.         0.        ]]
# 5         46.636784  [[-0.8222106   0.61390805  0.        ]]
# 6         45.697704  [[-0.42186913  1.          0.        ]]
# 7         47.256730        [[0.7500993 0.        0.       ]]
# 8         47.488373     [[-0.5868957  1.         0.       ]]
# 9         48.973690                          [[-1.  0.  0.]]
# 10        48.497590  [[-1.          0.99327743  0.        ]]
# 11        48.729393  [[-1.          0.20322931  0.        ]]
# 12        47.654964     [[0.97309744 0.19050515 0.        ]]
# 13        49.174570                          [[-1.  1.  0.]]
# ...

# %%
data.plot(y='value', figsize=(20,10))
