# %%
# %matplotlib inline
import matplotlib
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('values.csv')

# %%
data.set_index('timestep', inplace=True)

# %%
[a*50 for a in list(range(11))]
# Out:
# [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

# %%
plt.figure(figsize=(24,10))
plt.grid(b=True, linewidth=0.5)
plt.plot(data.index, data.value)
plt.xticks([a*50 for a in list(range(21))])
plt.xlabel('Timesteps', fontsize=18)
plt.ylabel('Value Function', fontsize=18)
plt.show()
